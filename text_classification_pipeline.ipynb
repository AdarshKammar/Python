# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshKammar/Python/blob/main/text_classification_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# Use a model fine-tuned for sentiment analysis
classifier = pipeline('text-classification', model='distilbert-base-uncased-finetuned-sst-2-english')

# Sample text for classification
texts = [
    "I love the weather today!",
    "I am feeling very sad about my exams.",
    "The movie was fantastic, really enjoyed it!",
    "This is the worst book I've ever read."
]

# Make predictions
predictions = classifier(texts)

# Display results
for text, prediction in zip(texts, predictions):
    print(f"Text: {text}")
    print(f"Prediction: {prediction['label']} with confidence: {prediction['score']}\n")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# Text: I love the weather today!
# Prediction: POSITIVE with confidence: 0.9998793601989746
#
# Text: I am feeling very sad about my exams.
# Prediction: NEGATIVE with confidence: 0.9989972710609436
#
# Text: The movie was fantastic, really enjoyed it!
# Prediction: POSITIVE with confidence: 0.9998724460601807
#
# Text: This is the worst book I've ever read.
# Prediction: NEGATIVE with confidence: 0.9997720122337341
